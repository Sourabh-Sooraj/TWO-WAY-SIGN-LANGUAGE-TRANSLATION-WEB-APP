# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
picarr=np.asarray(pic)

# %%
picarr
# Out:
# array([[[95, 81, 78],
#         [97, 83, 80],
#         [98, 84, 81],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [96, 82, 79],
#         [96, 82, 79],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [94, 80, 77],
#         [94, 80, 77],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        ...,
#
#        [[19, 29, 20],
#         [20, 30, 21],
#         [20, 30, 21],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [20, 30, 21],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [19, 29, 20],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]]], dtype=uint8)

# %%
picarr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(picarr)

# %%
picred=picarr.copy()
plt.imshow(picred)

# %%
plt.imshow(picred[:,:,0],cmap='gray')

# %%
b=np.ones(5)

# %%
b
# Out:
# array([1., 1., 1., 1., 1.])
